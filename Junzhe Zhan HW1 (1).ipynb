# %% [markdown]
# #### 1. Pick one of the datasets from the ChatBot session(s) of the **TUT demo** (or from your own ChatBot session if you wish) and use the code produced through the ChatBot interactions to import the data and confirm that the dataset has missing values<br>

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-05/villagers.csv"
df = pd.read_csv(url)
df.isna().sum()
# Out:
# row_n           0
# id              1
# name            0
# gender          0
# species         0
# birthday        0
# personality     0
# song           11
# phrase          0
# full_id         0
# url             0
# dtype: int64

# %% [markdown]
# #### 2. Start a new ChatBot session with an initial prompt introducing the dataset you're using and request help to determine how many columns and rows of data a `pandas` DataFrame has, and then
#
# 1. use code provided in your ChatBot session to print out the number of rows and columns of the dataset; and,
# 2. write your own general definitions of the meaning of "observations" and "variables" based on asking the ChatBot to explain these terms in the context of your dataset<br>

# %%
print(df.shape)
# Out:
# (391, 11)

# %% [markdown]
# Observations refer to the rows in the dataset. Each observation is a single unit from which the data has been collected.
# Variables refer to the columns in the dataset. Each variable is a type of information in the dataset.

# %% [markdown]
# #### 3. Ask the ChatBot how you can provide simple summaries of the columns in the dataset and use the suggested code to provide these summaries for your dataset<br>

# %%
# Display the first 5 rows of the dataset
print(df.head())
# Out:
#    row_n       id     name  gender    species birthday personality  \
# 0      2  admiral  Admiral    male       bird     1-27      cranky
# 1      3  agent-s  Agent S  female   squirrel      7-2       peppy
# 2      4    agnes    Agnes  female        pig     4-21        uchi
# 3      6       al       Al    male    gorilla    10-18        lazy
# 4      7  alfonso  Alfonso    male  alligator      6-9        lazy
#
#           song    phrase           full_id  \
# 0   Steep Hill   aye aye  villager-admiral
# 1      DJ K.K.  sidekick  villager-agent-s
# 2   K.K. House   snuffle    villager-agnes
# 3   Steep Hill   Ayyeeee       villager-al
# 4  Forest Life  it'sa me  villager-alfonso
#
#                                                  url
# 0  https://villagerdb.com/images/villagers/thumb/...
# 1  https://villagerdb.com/images/villagers/thumb/...
# 2  https://villagerdb.com/images/villagers/thumb/...
# 3  https://villagerdb.com/images/villagers/thumb/...
# ...

# %%
# Get a statistical summary of numerical columns
print(df.describe())
# Count of unique values in the 'species' column
print(df['gender'].value_counts())
# Out:
#             row_n
# count  391.000000
# mean   239.902813
# std    140.702672
# min      2.000000
# 25%    117.500000
# 50%    240.000000
# 75%    363.500000
# max    483.000000
# gender
# male      204
# female    187
# Name: count, dtype: int64

# %% [markdown]
# #### 4. If the dataset you're using has (a) non-numeric variables and (b) missing values in numeric variables, explain (perhaps using help from a ChatBot if needed) the discrepancies between size of the dataset given by `df.shape` and what is reported by `df.describe()` with respect to (a) the number of columns it analyzes and (b) the values it reports in the "count" column<br>

# %%
import pandas as pd
url =  "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %% [markdown]
# The size of the dataset given by df.shape is larger than what is reported by df.describe() with respect to the number of columns it analyzes.
# Because the df.describe() ignore all the non-numeric variables. The size of the dataset given by df.shape is larger or equal to what is reported by df.describe() with respect to the values it reports in the "count" column. Because df.describe() will ignore the missing values.

# %% [markdown]
# #### 5. Use your ChatBot session to help understand the difference between the following and then provide your own paraphrasing summarization of that difference
#
# - an "attribute", such as `df.shape` which does not end with `()`
# - and a "method", such as `df.describe()` which does end with `()`

# %% [markdown]
# Attibutes provide data and store information about data. It has already existed.They are the important properties of data.
# Methods perform operations to return results, they are not properties of data. They need to undergo some calculation to get the unknow result.

# %% [markdown]
# # Summaries of Chatbot

# %% [markdown]
# Here's a summary of the current session so far:
#
# Dataset Discussion:
#
# You mentioned having a dataset about Animal Crossing characters and asked about analyzing it.
# We discussed how to examine the size (dimensions) and columns of the dataset, but due to limitations, I couldn't access the online version. I suggested uploading the dataset for further analysis.
# Concept Clarifications:
#
# I explained key data concepts:
# Observations (rows, representing individual data points or instances).
# Variables (columns, representing attributes or features of the observations).
# We also discussed how to generate simple summaries of the columns, such as summary statistics for numerical data and frequency counts for categorical data.
# Programming Concepts:
#
# You asked about the difference between attributes and methods in object-oriented programming:
# Attributes hold the state or data of an object.
# Methods define the actions or behaviors an object can perform.

# %% [markdown]
# Link: https://chatgpt.com/share/66e35466-7dd0-800b-ade9-dac0afa87d66

# %% [markdown]
# #### 6. The `df.describe()` method provides the 'count', 'mean', 'std', 'min', '25%', '50%', '75%', and 'max' summary statistics for each variable it analyzes. Give the definitions (perhaps using help from the ChatBot if needed) of each of these summary statistics<br>

# %% [markdown]
# count: The number of non-missing (non-NaN) values in the column.
#
# mean: The arithmetic average of the non-missing values.
#
# std: The standard deviation, which measures the dispersion or spread of the non-missing values.
#
# min: The minimum value in the column, excluding missing values.
#
# 25%: The 25th percentile (first quartile), which is the value below which 25% of the non-missing values fall.
#
# 50%: The 50th percentile (median), which is the value below which 50% of the non-missing values fall.
#
# 75%: The 75th percentile (third quartile), which is the value below which 75% of the non-missing values fall.
#
# max: The maximum value in the column, excluding missing values.

# %% [markdown]
# By default, it summarizes numeric columns, but it can also be configured to include non-numeric data.

# %% [markdown]
# #### 7. Missing data can be considered "across rows" or "down columns".  Consider how `df.dropna()` or `del df['col']` should be applied to most efficiently use the available non-missing data in your dataset and briefly answer the following questions in your own words

# %% [markdown]
# 1. Provide an example of a "use case" in which using `df.dropna()` might be peferred over using `del df['col']`<br><br>

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, None, 22],
        'City': ['New York', None, 'Chicago', 'San Francisco']}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name   Age           City
# 0    Alice  25.0       New York
# 1      Bob  30.0           None
# 2  Charlie   NaN        Chicago
# 3    David  22.0  San Francisco

# %% [markdown]
# When the data is not concentrated in a single column but is scattered across several rows, using df.dropna() is better than using del df['col']. This is because using del df['col'] may delete the entire column, even though the column might have only one missing value. This can result in the dataset becoming incomplete.

# %% [markdown]
# 2. Provide an example of "the opposite use case" in which using `del df['col']` might be preferred over using `df.dropna()` <br><br>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)

# %%
print(df.isna().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# When missing data is gathered in some spercific columns, using del df['col'] might be preferred over using df.dropna(). This is because using df.dropna() will delete all rows containing missing values, directly removing a large amount of data.

# %% [markdown]
# 3. Discuss why applying `del df['col']` before `df.dropna()` when both are used together could be important<br><br>

# %% [markdown]
# Deleting columns with excessive missing values before applying df.dropna() can greatly reduce the size of the dataset which can reduce the complexity of the dataset.It will also improve the efficiency by deleting unnecessary columns.

# %% [markdown]
# 4. Remove all missing data from one of the datasets you're considering using some combination of `del df['col']` and/or `df.dropna()` and give a justification for your approach, including a "before and after" report of the results of your approach for your dataset.<br><br>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)

# %%
missing_summary = df.isna().sum()
print(missing_summary)
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
del df['age']
del df['deck']

# %%
missing_summary_after_columns_removal = df.isna().sum()
print(missing_summary_after_columns_removal)
# Out:
# survived       0
# pclass         0
# sex            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df_cleaned = df.dropna()

# %%
print(f"Original dataset shape: {df.shape}")
# Out:
# Original dataset shape: (891, 13)

# %%
print(f"Dataset shape after cleaning: {df_cleaned.shape}")
# Out:
# Dataset shape after cleaning: (889, 13)

# %% [markdown]
# I remove the columns "age"and"deck" which have excessive missing data. Then I drop rows with remaining missing values:"embarked"and"embark_town".

# %% [markdown]
# ## Summaries of Chatbot

# %% [markdown]
# df.dropna(): Removes rows with any missing values. Useful for cleaning up data by discarding incomplete rows.
# del df['col']: Removes a specific column entirely. Useful when you no longer need that column, regardless of its content.
# In this case, df.dropna() is better for handling missing data while preserving the other columns, whereas del df['City'] would remove the entire column if you don't need it at all.

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, None, 22],
        'City': ['New York', None, 'Chicago', 'San Francisco']}

df = pd.DataFrame(data)
print(df)

# %%
      Name   Age           City
0    Alice  25.0       New York
1      Bob  30.0            NaN
2  Charlie   NaN        Chicago
3    David  22.0  San Francisco

# %%
df_cleaned = df.dropna()
print(df_cleaned)

# %%
    Name   Age         City
0  Alice  25.0     New York
3  David  22.0  San Francisco

# %%
del df['City']
print(df)

# %%
      Name   Age
0    Alice  25.0
1      Bob  30.0
2  Charlie   NaN
3    David  22.0

# %% [markdown]
# Link: https://chatgpt.com/share/66e359f2-0a64-800b-b67f-d73de9b42cbc

# %% [markdown]
# #### 8. Give brief explanations in your own words for any requested answers to the questions below

# %% [markdown]
# 1. Use your ChatBot session to understand what `df.groupby("col1")["col2"].describe()` does and then demonstrate and explain this using a different example from the "titanic" data set other than what the ChatBot automatically provide for you

# %%
# Group by 'sex' and get summary statistics for 'aimport pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)ge'
summary_stats = df.groupby("sex")["age"].describe()
print(summary_stats)
# Out:
#         count       mean        std   min   25%   50%   75%   max
# sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %% [markdown]
# When you run the above code, you'll get a table with summary statistics for the age column, grouped by the sex column.

# %% [markdown]
# 2. Assuming you've not yet removed missing values in the manner of question "7" above, `df.describe()` would have different values in the `count` value for different data columns depending on the missingness present in the original data.  Why do these capture something fundamentally different from the values in the `count` that result from doing something like `df.groupby("col1")["col2"].describe()`?

# %% [markdown]
# When you use df.groupby("col1")["col2"].describe(), you are computing summary statistics for col2 within each group defined by col1. When you use df.describe(), it provides summary statistics for all numerical columns in the DataFrame. The count value in this context reflects the number of non-missing (non-null) entries in each column across the entire DataFrame.

# %% [markdown]
# ### Summaries of Chatbot

# %% [markdown]
# Session Summary
# Objective: Understand and analyze the Titanic dataset using different summary statistics methods in pandas, particularly focusing on how missing values affect these statistics.
#
# Methods Discussed:
#
# df.describe(): Provides summary statistics for numerical columns in the entire DataFrame, including the count of non-null values, mean, standard deviation, quartiles, and maximum/minimum values.
# df.groupby("col1")["col2"].describe(): Offers summary statistics for a specific column grouped by another column. This method gives insight into the distribution of the data within each group and the count of non-null values for each group.

# %% [markdown]
# Link: https://chatgpt.com/share/66e35b08-34a0-800b-9cc4-f04d0b347b66

# %% [markdown]
# 3. Intentionally introduce the following errors into your code and report your opinion as to whether it's easier to (a) work in a ChatBot session to fix the errors, or (b) use google to search for and fix errors: first share the errors you get in the ChatBot session and see if you can work with ChatBot to troubleshoot and fix the coding errors, and then see if you think a google search for the error provides the necessary toubleshooting help more quickly than ChatGPT<br><br>

# %% [markdown]
# 1. Forget to include `import pandas as pd` in your code

# %%
import pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)

# %%
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv(url)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# This is what ChatGPT said: It looks like you encountered a NameError because the name pd isn't recognized. This usually happens when you haven't imported the necessary library or module. In your case, it seems like you need to import the pandas library before using it.
#
# Here's how you can fix this:

# %%
import pandas as pd

# Replace 'url' with the actual URL or file path of your CSV
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 2. Mistype "titanic.csv" as "titanics.csv"
#        <br>

# %%
import pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanics.csv'
df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 # Load the Titanic dataset
#       4 url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanics.csv'
# ----> 5 df = pd.read_csv(url)
#
# ...

# %% [markdown]
# This is what ChatGPT said: The HTTPError 404: Not Found indicates that the URL you're trying to access does not exist or cannot be found on the server. This might happen if there is a typo in the URL or if the resource has been moved or deleted.

# %%
import pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 3. Try to use a dataframe before it's been assigned into the variable
#        <br>

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
# ----> 4 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# This is what ChatGPT said: The NameError: name 'df' is not defined indicates that the variable df does not exist in the current scope, likely because it was not successfully created or defined earlier in your code.
#
# To resolve this issue, ensure the following:
#
# Check for Successful Data Loading: Make sure that the DataFrame df was successfully created by loading the CSV file. If there were errors in the previous steps (such as a typo or a broken URL), df would not be defined.
#
# Verify All Code Execution: Ensure that all relevant code cells have been executed in the correct order if you’re using a Jupyter notebook or similar environment.
#
# Check for Errors in Previous Cells: If there were errors in previous cells (e.g., while reading the CSV), they need to be resolved before df can be defined.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 4. Forget one of the parentheses somewhere the code
#        <br>

# %%
import pandas as pd

# Replace 'url' with the actual URL or file path of your CSV
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
# Out:
#   Cell In[7], line 4
#     df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#                                                                                                 ^
# SyntaxError: incomplete input

# %% [markdown]
# It looks like you have a SyntaxError because the line of code is missing a closing parenthesis. In Python, every opening parenthesis ( must have a corresponding closing parenthesis ).

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 5. Mistype one of the names of the chained functions with the code
#        <br>

# %%
import pandas as pd

# Replace 'url' with the actual URL or file path of your CSV
df = pd.ead_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
# Out:
#   Cell In[8], line 4
#     df = pd.ead_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#                                                                                                ^
# SyntaxError: incomplete input

# %% [markdown]
# It looks like there's a typo in the method name pd.ead_csv, which should be pd.read_csv. Additionally, it seems like you might be missing a closing parenthesis at the end of the line.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 6. Use a column name that's not in your data for the `groupby` and column selection
#        <br>

# %%
# Group by 'sex' and get summary statistics for 'aimport pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)ge'
summary_stats = df.groupby("dog")["cat"].describe()
print(summary_stats)
# Out:
#   Cell In[9], line 5
#     df = pd.read_csv(url)ge'
#                            ^
# SyntaxError: unterminated string literal (detected at line 5)

# %% [markdown]
# he error message SyntaxError: unterminated string literal suggests that there’s a problem with how a string is terminated in your code. It looks like there might be extra characters or a misplaced quote in your line of code.
#
# Here’s how you can correct it:
#
# Check for Typographical Errors: Make sure there are no extra characters or misplaced quotes.
#
# Ensure Proper String Termination: Verify that all strings are properly enclosed in single ' or double " quotes.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# 7. Forget to put the column name as a string in quotes for the `groupby` and column selection, and see if the ChatBot and google are still as helpful as they were for the previous question
#        <br>

# %%
# Group by 'sex' and get summary statistics for 'aimport pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
summary_stats = df.groupby(sex)[age].describe()
print(summary_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 6
#       4 url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#       5 df = pd.read_csv(url)
# ----> 6 summary_stats = df.groupby(sex)[age].describe()
#       7 print(summary_stats)
#
# NameError: name 'sex' is not defined

# %% [markdown]
# It looks like there's an issue with the code around the string literal. Specifically, it seems like there’s an extra or misplaced character, such as ge', that shouldn't be there.
#
# Here’s how you can resolve this:
#
# Remove Any Extra Characters: Ensure that your line of code contains only the correct syntax.
#
# Verify Proper String Closure: Make sure the URL string is correctly enclosed.

# %%
# Group by 'sex' and get summary statistics for 'aimport pandas as pd

# Load the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
df = pd.read_csv(url)
summary_stats = df.groupby("sex")["age"].describe()
print(summary_stats)
# Out:
#         count       mean        std   min   25%   50%   75%   max
# sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %% [markdown]
# ## Summaries of ChatGPT

# %% [markdown]
# Initial Issue: You faced a NameError because pandas (pd) was not imported. You resolved it by importing pandas.
#
# HTTPError: You encountered an HTTPError due to a 404 Not Found error with a URL for a dataset. The URL was updated to a correct one.
#
# Syntax Errors: You had syntax errors including an incomplete function call and an unterminated string literal. These were fixed by ensuring proper syntax and parentheses.
#
# NameError in Code: You faced a NameError because column names were not properly passed as strings in the groupby function.

# %%
import pandas as pd

# URL of the Titanic dataset
url = 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# Group by 'sex' and describe 'age'
summary_stats = df.groupby('sex')['age'].describe()
print(summary_stats)

# %% [markdown]
# The output will display descriptive statistics (like count, mean, standard deviation, min, 25th percentile, median, 75th percentile, and max) for the 'age' column, grouped by 'sex'.
#
# If you run this code, it will produce a summary table showing these statistics for each sex group.

# %% [markdown]
# Link: https://chatgpt.com/share/66e35dd9-7640-800b-b1ab-a39d8edcce81

# %% [markdown]
# #### 9. Have you reviewed the course [wiki-textbook](https://github.com/pointOfive/stat130chat130/wiki) and interacted with a ChatBot (or, if that wasn't sufficient, real people in the course piazza discussion board or TA office hours) to help you understand all the material in the tutorial and lecture that you didn't quite follow when you first saw it?<br>

# %% [markdown]
# Yes.
