# %%
import pandas as pd
cols = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")

data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only

data.shape
# Out:
# /tmp/ipykernel_89/1186939764.py:4: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
# (11431, 1779)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 假设您的数据在一个DataFrame中
# 示例数据
data1 = {
    'WELLNESS_malach_pines_burnout_measure_hopeless': [data['WELLNESS_malach_pines_burnout_measure_hopeless']],
    'CONNECTION_social_days_family_p7d_grouped': [data['CONNECTION_social_days_family_p7d_grouped']]
}
df = pd.DataFrame(data1)

# 创建交叉表
cross_tab = pd.crosstab(df['WELLNESS_malach_pines_burnout_measure_hopeless'],
                        df['CONNECTION_social_days_family_p7d_grouped'])

# 绘制堆叠柱状图
cross_tab.plot(kind='bar', stacked=True, figsize=(8, 6))
plt.title('Relationship between Wellness and Family Connection')
plt.xlabel('Burnout Measure (Hopeless)')
plt.ylabel('Count')
plt.legend(title='contact with Family (Past 7 days)')
plt.tight_layout()

# 显示图表
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
cols = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")

data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only

# 去除列名中的多余空格
data.columns = data.columns.str.strip()

# 确保列为分类变量
df['WELLNESS_malach_pines_burnout_measure_hopeless'] = df['WELLNESS_malach_pines_burnout_measure_hopeless'].astype('category')
df['CONNECTION_activities_talked_family_p3m'] = df['CONNECTION_activities_talked_family_p3m'].astype('category')

# 绘制箱线图
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=df,
    x='CONNECTION_activities_talked_family_p3m',
    y='WELLNESS_malach_pines_burnout_measure_hopeless',
    palette='Set2'
)

# 添加标题和标签
plt.title('Boxplot: Talking to Family and Hopelessness', fontsize=14)
plt.xlabel('Talked to Family (Past 3 Months)', fontsize=12)
plt.ylabel('Hopelessness Measure', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()

# 显示图表
plt.show()
# Out:
# /tmp/ipykernel_89/1384769053.py:8: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/pandas/core/arrays/categorical.py:449, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     448 try:
# --> 449     codes, categories = factorize(values, sort=True)
#     450 except TypeError as err:
#
# ...

# %%
import pandas as pd
from scipy.stats import chi2_contingency


cols = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")

data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only



# 选择相关变量并去除缺失值
data = df[['WELLNESS_malach_pines_burnout_measure_hopeless', 'CONNECTION_activities_talked_family_p3m']].dropna()

# 创建列联表（Crosstab）
crosstab = pd.crosstab(data['CONNECTION_activities_talked_family_p3m'],
                       data['WELLNESS_malach_pines_burnout_measure_hopeless'])

# 执行卡方检验
chi2, p, dof, expected = chi2_contingency(crosstab)

# 打印结果
print("Chi-Square Test Results:")
print(f"Chi-Square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies Table:")
print(expected)

# 判定结果
alpha = 0.05  # 显著性水平
if p < alpha:
    print("Reject the null hypothesis: The variables are dependent.")
else:
    print("Fail to reject the null hypothesis: The variables are independent.")
# Out:
# /tmp/ipykernel_89/1968623535.py:7: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 15
#      10 data = data[empty.index[~empty]] # keep non empty columns only
#      14 # 选择相关变量并去除缺失值
# ---> 15 data = df[['WELLNESS_malach_pines_burnout_measure_hopeless', 'CONNECTION_activities_talked_family_p3m']].dropna()
#      17 # 创建列联表（Crosstab）
# ...

# %%
# Re-importing the necessary libraries
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import pandas as pd
cols = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")

data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only

# Strip column names to remove any extra spaces
data.columns = data.columns.str.strip()

# Check the correct column names and select the relevant columns
try:
    data = data[['WELLNESS_malach_pines_burnout_measure_depressed', 'CONNECTION_activities_community_p3m']].dropna()

    # Encode categorical variables
    label_encoder_dep = LabelEncoder()
    label_encoder_com = LabelEncoder()

    data['depressed_encoded'] = label_encoder_dep.fit_transform(data['WELLNESS_malach_pines_burnout_measure_depressed'])
    data['community_encoded'] = label_encoder_com.fit_transform(data['CONNECTION_activities_community_p3m'])

    # Prepare features (X) and target (y)
    X = data[['community_encoded']]
    y = data['depressed_encoded']

    # Initialize and train the Decision Tree Classifier
    clf = DecisionTreeClassifier(max_depth=3, random_state=42)
    clf.fit(X, y)

    # Plot the classification tree
    plt.figure(figsize=(12, 8))
    plot_tree(clf, feature_names=['Community Activities'], class_names=label_encoder_dep.classes_, filled=True, rounded=True)
    plt.title('Classification Tree: Community Activities and Depression Levels')
    plt.show()

except KeyError as e:
    print(f"KeyError: {e}. Please check the column names in the dataset.")
    print("Available columns:", df_uploaded.columns.tolist())
# Out:
# /tmp/ipykernel_52/4289132273.py:8: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cols = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/var_names.csv")

data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only




# 清理列名，去除多余的空格
data.columns = data.columns.str.strip()

# 检查数据集中是否包含所需的列
if 'CONNECTION_activities_visited_family_p3m' in data.columns and \
   'LONELY_dejong_emotional_social_loneliness_scale_emptiness' in data.columns:
    
    # 选择相关数据并去除缺失值
    data = data[['CONNECTION_activities_visited_family_p3m', 
                        'LONELY_dejong_emotional_social_loneliness_scale_emptiness']].dropna()

    # 创建交叉表以进行可视化
    crosstab_data = pd.crosstab(data['CONNECTION_activities_visited_family_p3m'],
                                data['LONELY_dejong_emotional_social_loneliness_scale_emptiness'])

    # 绘制热图以可视化关系
    plt.figure(figsize=(12, 8))
    sns.heatmap(crosstab_data, annot=True, fmt="d", cmap="coolwarm", cbar=True)
    plt.title('Relationship between Visiting Family and Loneliness (Emptiness)', fontsize=14)
    plt.xlabel('Loneliness (Emptiness Scale)', fontsize=12)
    plt.ylabel('Visited Family (Past 3 Months)', fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("所需的列在数据集中不存在。请检查列名。")
    print("可用的列名:", data.columns.tolist())
# Out:
# /tmp/ipykernel_52/2118999640.py:7: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/main/CP/CSCS_data_anon.csv",
